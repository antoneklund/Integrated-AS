# %%
from simulation import *
from sampling import sampling_from_a_finite_population

# %%
print(sampling_from_a_finite_population(epsilon=0.1, population_size=1000, pi=0.5))
# Out:
# 88

# %%
# LANGUAGE = "danish"
LANGUAGE = "english"
# LANGUAGE = "swedish"
# LANGUAGE = "seventy"
# LANGUAGE = "eighty"
# LANGUAGE = "ninetyfive"

plot_truncation_simulation(lang=LANGUAGE, iterations=20,
                      truncation=True, acceptance_limit=0.9, pi=0.9)
# Out:
# ['accept', 'accept', 'reject', 'reject', 'accept', 'accept', 'accept', 'accept', 'accept', 'accept', 'accept', 'accept', 'reject', 'accept', 'accept', 'accept', 'accept', 'accept', 'accept', 'accept']

# %%
# x_scatter is where the points in the scatter plot should be placed
oc_curve(n_values = [34, 136, 10000], acceptance_limit = 0.9, x_scatter = [0.081, 0.086, 0.128], scatter_labels=["ENG", "SWE", "DAN"])
# Out:
# /home/anton/.local/lib/python3.10/site-packages/scipy/stats/_discrete_distns.py:78: RuntimeWarning: divide by zero encountered in _binom_pdf
#   return _boost._binom_pdf(x, n, p)

# %%
samples_until_decision(max_samples=136, acceptance_limit=0.9, num_simulations=1000)

# %%
pi_vs_n()
